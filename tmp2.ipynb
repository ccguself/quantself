# %%
import h5py

# %%
raw_db = h5py.File("d:\\Books\\Data\\20220825_L2Order.h5", "r")

# %%
for i, name in enumerate(raw_db):
    print(name)
# Out:
# SH.510050
# SH.510300

# %%
import pandas as pd

# %%
df = pd.read_hdf("d:\\Books\\Data\\20220825_L2Tran.h5", "SH.510300")

# %%
df["cul"] = 1

# %%
df["cul"] = df["cul"].cumsum()

# %%
df.iloc[-500:]
# Out:
#        ActionDate    SeqNo  Channel     ExTime  Price  Volume  Turnover  \
# 34025    20220825  6670595        6  145803370  41800    3000     12540
# 34026    20220825  6670596        6  145803370  41800    1000      4180
# 34027    20220825  6670597        6  145803370  41800   16200     67716
# 34028    20220825  6670598        6  145803370  41800     100       418
# 34029    20220825  6670599        6  145803370  41800    1000      4180
# ...           ...      ...      ...        ...    ...     ...       ...
# 34520    20220825  6673465        6  145957330  41820   15600     65239
# 34521    20220825  6673466        6  145957330  41820     700      2927
# 34522    20220825  6673547        6  145959600  41820    3500     14637
# 34523    20220825  6673552        6  145959850  41820     800      3346
# 34524    20220825  6673553        6  145959850  41820    1200      5018
#
#           BidNo     AskNo  BSFlag    cul
# 34025  11416429  11297839      66  34026
# ...
